# %%
from bs4 import BeautifulSoup
import requests
import io
import csv
import pandas as pd

# %%
url = 'https://www.abdurraqib.com/publications'

response = requests.get(url)

soup = BeautifulSoup(response.content, 'html.parser')

content_div = soup.find('div', class_='sqs-html-content')
#ontent = soup.find_all('p', class_='sqs-html-content')
if content_div: 
 #   for para in content_div.find_all('p'):
  #      with open("hanif_a.txt", "w") as f:
   #         f.write(para.text.strip())
       # csv = para.text.strip()
    #with open("hanif_a.txt", "w") as f:
     #           f.write(csv)
    with open("hanif_a.txt", "w") as f:
         for para in content_div.find_all('p'):
          f.write(para.get_text() + "\n")
          
else:
    print("unable to find content :(())")
#print(conten)

# %%
file = pd.read_csv("hanif_a.txt", sep='')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2400/3180231871.py in <module>
# ----> 1 file = pd.read_csv("hanif_a.txt", sep='')
#
# c:\Users\sehbs\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
